# %%
! pip install kaggle

# %%
# !sudo apt-get install unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1.1).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !ls
# Out:
# kaggle.json  sample_data

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !mkdir SteamStore

# %%
# !mkdir SteamGames

# %%
# !mkdir SteamReviews

# %%
# !mkdir Steamnlp

# %%
# %cd SteamStore
! kaggle datasets download -d nikdavis/steam-store-raw
# %cd ..
# Out:
# /content/SteamStore
# ...
#  86% 46.0M/53.4M [00:00<00:00, 172MB/s]
# 100% 53.4M/53.4M [00:00<00:00, 102MB/s]
# /content

# %%
# %cd SteamGames
# !kaggle datasets download -d nikdavis/steam-store-games
# %cd ..
# Out:
# /content/SteamGames
# ...
#  80% 28.0M/35.2M [00:00<00:00, 104MB/s]
# 100% 35.2M/35.2M [00:00<00:00, 102MB/s]
# /content

# %%
# %cd SteamReviews
# !kaggle datasets download -d nourelkamel/steam-reviews
# %cd ..
# Out:
# /content/SteamReviews
# ...
# 100% 3.51G/3.52G [00:33<00:00, 150MB/s]
# 100% 3.52G/3.52G [00:33<00:00, 112MB/s]
# /content

# %%
# %cd Steamnlp
# !kaggle datasets download -d zeeenb/steamreviewsnlp
# %cd ..
# Out:
# /content/Steamnlp
# ...
# 100% 3.52G/3.53G [00:26<00:00, 134MB/s]
# 100% 3.53G/3.53G [00:26<00:00, 141MB/s]
# /content

# %%
# %cd SteamGames
! unzip steam-store-games.zip
# Out:
# /content/SteamGames
# Archive:  steam-store-games.zip
#   inflating: steam.csv
#   inflating: steam_description_data.csv
#   inflating: steam_media_data.csv
#   inflating: steam_requirements_data.csv
#   inflating: steam_support_info.csv
#   inflating: steamspy_tag_data.csv

# %%
# %cd ..
# Out:
# /content

# %%
# %cd Steamnlp
# !unzip steamreviewsnlp.zip
# Out:
# /content/Steamnlp
# Archive:  steamreviewsnlp.zip
#   inflating: cleanGameInfo.csv
#   inflating: db.csv
#   inflating: reviewAndGameInfoJoined.csv
#   inflating: uncleanGameInfo.csv

# %%
# %cd ..
# Out:
# /content

# %%
# %cd SteamReviews
# !unzip steam-reviews.zip
# Out:
# /content/SteamReviews
# Archive:  steam-reviews.zip
#   inflating: all_reviews.csv
#   inflating: db.csv
#   inflating: game_db.csv

# %%
# %cd ..
# Out:
# /content

# %%
# %cd SteamStore
# !unzip steam-store-raw.zip
# Out:
# /content/SteamStore
# Archive:  steam-store-raw.zip
#   inflating: app_list.csv
#   inflating: steam_app_data.csv
#   inflating: steamspy_data.csv

# %%
# %cd ..
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
