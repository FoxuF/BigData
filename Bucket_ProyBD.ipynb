# %%
# %pip install gsutil
# Out:
# ...
#      |████████████████████████████████| 2.9 MB 13.2 MB/s
# ...
#      |████████████████████████████████| 135 kB 43.1 MB/s
# ...
#      |████████████████████████████████| 96 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 55 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 156 kB 28.9 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 37.8 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 55.5 MB/s
# ...
#      |████████████████████████████████| 144 kB 70.5 MB/s
# ...
#      |████████████████████████████████| 94 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 271 kB 56.8 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 52.2 MB/s
# ...
#   Created wheel for gsutil: filename=gsutil-5.10-py3-none-any.whl size=3746901 sha256=9cd67ab341d1782bba362f6ffdd34190b2151f979e848ad2097dbfe77a67a352
#   Stored in directory: /root/.cache/pip/wheels/aa/88/65/707e8d8cd23806e0746ebb1fa02648b728d9efa9998d9a7e7e
# ...

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()
#Deben iniciar sesion con la cuenta de la up para que les deje ver mi proyecto
gc = gspread.authorize(creds)

# %%
# !gsutil config 
 #Este es el Project-ID: bigdata-342102
# Out:
# This command will create a boto config file at /root/.boto containing
# your credentials, based on your responses to the following questions.
# Please navigate your browser to the following URL:
# https://accounts.google.com/o/oauth2/auth?client_id=909320924072.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&access_type=offline&response_type=code
# In your browser you should see a page that requests you to authorize access to Google Cloud Platform APIs and Services on your behalf. After you approve, an authorization code will be displayed.
#
# Enter the authorization code: 4/1AX4XfWjbIIkgMheQCjJRq6gu-IzVxFC8MWdaT-sRcoCXvd7XnSCczU9cciQ
#
# Please navigate your browser to https://cloud.google.com/console#/project,
# then find the project you will use, and copy the Project ID string from the
# ...

# %%
#Muestra cuanto pesa todos los CSV
# !gsutil du -hs "gs://bucket-foxu/*.csv"
# Out:
# 226.96 MiB   gs://bucket-foxu/*.csv

# %%
# !gsutil ls gs://bucket-foxu
# Out:
# gs://bucket-foxu/carpetas_investigacion.csv

# %%
# %pip install hive

# %%
# !mkdir proyecto_steam
# Out:
# mkdir: cannot create directory ‘proyecto_steam’: File exists

# %%
# !pip install pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession \
    .builder \
    .appName("Proyecto Steam") \
    .config("spark.sql.warehouse.dir", '/user/proyecto_steam/spark') \
    .enableHiveSupport() \
    .getOrCreate()

# %%
spark.getActiveSession()
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://b72feb3850ec:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Proyecto Steam</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.write.option("header", True).csv("hdfs://user/proyecto_Steam/")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-27ed3f23e47a> in <module>()
# ----> 1 df = spark.write.option("header", True).csv("hdfs://user/proyecto_Steam/")
#
# AttributeError: 'SparkSession' object has no attribute 'write'

# %%
spark.stop()
